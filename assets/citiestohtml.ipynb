# %%
import pandas as pd

# %%
csv_file = "cities.csv"
cities_csv = pd.read_csv(csv_file)
cities_df = pd.DataFrame(cities_csv)

# %%
cities_df.head()
# Out:
#    Unnamed: 0       City  Temperature  Latitude  Longitude  Cloudiness  \
# 0           0    rikitea        25.04  -23.1203  -134.9692          15
# 1           1     broome         7.46   42.2506   -75.8330          26
# 2           2       atar        35.20   20.5169   -13.0499          23
# 3           3     mudgal        27.31   16.0167    76.4333          50
# 4           4  bathsheba        29.00   13.2167   -59.5167          40
#
#    Wind_Speed  Humidity
# 0        3.09        76
# 1        1.79        54
# 2        6.59        11
# 3       10.57        47
# 4        8.23        54

# %%
del cities_df['Unnamed: 0']

# %%
cities_df
# Out:
#              City  Temperature  Latitude  Longitude  Cloudiness  Wind_Speed  \
# 0         rikitea        25.04  -23.1203  -134.9692          15        3.09
# 1          broome         7.46   42.2506   -75.8330          26        1.79
# 2            atar        35.20   20.5169   -13.0499          23        6.59
# 3          mudgal        27.31   16.0167    76.4333          50       10.57
# 4       bathsheba        29.00   13.2167   -59.5167          40        8.23
# ..            ...          ...       ...        ...         ...         ...
# 542   zapolyarnyy         1.00   69.4154    30.8136          40        2.06
# 543        taltal        19.30  -25.4000   -70.4833          16        1.83
# 544   pangnirtung         2.00   66.1451   -65.7125          90        2.06
# 545      dipalpur        30.56   30.6709    73.6529           1        2.71
# 546  vangaindrano        22.09  -23.3500    47.6000          36        1.57
#
#      Humidity
# 0          76
# 1          54
# 2          11
# 3          47
# 4          54
# ..        ...
# 542        80
# 543        68
# 544        87
# 545        15
# 546        91
#
# [547 rows x 7 columns]

# %%
cities_df.to_html('cities.html')
